# %% [markdown]
# # Matplotlib

# %%
#@title Functional Matplotlib example
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(100,500,11)
y=x**2

# %%
x
# Out:
# array([100., 140., 180., 220., 260., 300., 340., 380., 420., 460., 500.])

# %%
y
# Out:
# array([ 10000.,  19600.,  32400.,  48400.,  67600.,  90000., 115600.,
#        144400., 176400., 211600., 250000.])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
#@title Add X and Y Label and Title

# %%
plt.plot(x,y)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Sample Plot")
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %%
#@title Multiplot/Subplot on same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#@title Object Oriented Matplotlib example
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Sample Plot")
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %%
#@title Object Oriented Matplotlib example with 2 figures
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.46,0.2,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes2.plot(y,x)
axes1.set_title("Larger Plot")
axes2.set_title("Smaller Plot")
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
#@title Multiplot/Subplot Using Object oriented Matplotlib
#Subplot function creates axis for you based on number of rows and column
fig,axes=plt.subplots(nrows=1,ncols=2)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)

# %%
#@title Use tight layout to avoid overlapping
fig,axes=plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].set_title("FirstPlot")
axes[1].set_title("SecondPlot")
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
#@title Figure size aspect ratio and DPI
#3->Width in inches,2->Height in inches
fig=plt.figure(figsize=(3,2)) 
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig=plt.figure(figsize=(3,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)

# %%
fig=plt.figure(figsize=(8,2))
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig=plt.figure(figsize=(8,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)

# %%
#Change figure size for subplots
fig,axes=plt.subplots(figsize=(8,2))
axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
#@title Save a figure
fig.savefig("my_picture.png",dpi=500)

# %%
#@title Legends for multiple plots in the same axes
fig=plt.figure(figsize=(8,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.set_title("Multiple Plots")
# Out:
# Text(0.5, 1.0, 'Multiple Plots')

# %%
fig=plt.figure(figsize=(8,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,label="Twice")
axes.plot(x,x**3,label="Thrice")
axes.set_title("Multiple Plots")
axes.legend()

# %%
#Changing positions of legend(https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.legend.html)
fig=plt.figure(figsize=(8,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,label="Twice")
axes.plot(x,x**3,label="Thrice")
axes.set_title("Multiple Plots")
axes.legend(loc=9)

# %%
#USing tuple just like for axes to specify legends
fig=plt.figure(figsize=(8,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,label="Twice")
axes.plot(x,x**3,label="Thrice")
axes.set_title("Multiple Plots")
axes.legend(loc=(0.5,0.1))

# %%
#@title Changing color of the plot
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green")

# %%
#@title Changing color of the plot through RGB Hex code
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00")

# %%
#@title Changing linewidth and linestyle
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5)

# %%
#@title Use alpha to Make the line more or less transparent
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5,alpha=0.5)

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5,alpha=0.1)

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5,alpha=0.9)

# %%
#@title Change Style of line ex:dashed dotted
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5,alpha=0.9,linestyle="dashed")

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5,alpha=0.9,linestyle="dotted")

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="#FF8C00",linewidth=5,alpha=0.9,linestyle="steps")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#@title Show markers for X for which values are plotted in the axes
x
# Out:
# array([100., 140., 180., 220., 260., 300., 340., 380., 420., 460., 500.])

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green",linewidth=5,alpha=0.3,linestyle="dashed")

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green",linewidth=5,alpha=0.2,linestyle="dashed",marker="o")

# %%
#@title Making bigger markers
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green",linewidth=5,alpha=0.2,linestyle="dashed",marker="o",markersize=10)

# %%
#@title Specify marker color,markeredgewidth,markeredgecolor
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green",linewidth=3,alpha=0.5,linestyle="dashed",marker="o",markersize=20,markerfacecolor="red",markeredgewidth="3",markeredgecolor="blue")

# %%
#@title Control over axis appearance  and plot range
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green",linewidth=3,alpha=0.5,linestyle="dashed",marker="o",markersize=20,markerfacecolor="red",markeredgewidth="3",markeredgecolor="blue")
axes.set_xlim([100,350])
# Out:
# (100.0, 350.0)

# %%
fig=plt.figure() 
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="green",linewidth=3,alpha=0.5,linestyle="dashed",marker="o",markersize=20,markerfacecolor="red",markeredgewidth="3",markeredgecolor="blue")
axes.set_ylim([0,50000])
# Out:
# (0.0, 50000.0)

# %% [markdown]
# # Seaborne

# %%
#@title 1.Distribution Plots

# %%
#load built in tips dataset
import seaborn as sns
tips=sns.load_dataset("tips")

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#Histogram to show distribution of where your total_bill lies(Y axis has counts X has total bill)
sns.distplot(tips["total_bill"],kde=False)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips[(tips["total_bill"]>=10) & (tips["total_bill"]<=20)].describe()
# Out:
#        total_bill         tip        size
# count  130.000000  130.000000  130.000000
# mean    14.870077    2.455231    2.223077
# std      2.769154    0.767886    0.532151
# min     10.070000    1.000000    1.000000
# 25%     12.667500    2.000000    2.000000
# 50%     15.050000    2.305000    2.000000
# 75%     17.212500    3.000000    2.000000
# max     19.820000    4.300000    4.000000

# %%
#@title Changing number of Bins for a distribution plot
sns.distplot(tips["total_bill"],kde=False,bins=30)

# %%
sns.distplot(tips["total_bill"],kde=False,bins=100)

# %%
sns.distplot(tips["total_bill"],kde=False,bins=3)

# %%
#@title Joint Plot -> to combine two distribution plots(bi variate data or 2 variables)

# %%
#shows how tips is propotional to total_bill
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
#@title kind parameter to change what is happening inside jointplot,
#Hexagon gets darker if it has more number of points instead of having all scatter points on
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="regression")

# %%
#@title This shows a 2 dimensional KDE which effectively shows you density of where these points match up the most 
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde")

# %%
#@title Pairpplot -> is going to plot pairwise relationships across an entire dataframe atleast numerical columns
# It is going to do a joinplot for every single combination of numerical colums in this dataframe
#column vs column is a histogram instead because a scatter plot would show straight line
sns.pairplot(tips)

# %%
#@title Use hue argument in Pairplots to mark the categorical colums in the data points ex:Sex

sns.pairplot(tips,hue="sex")

# %%
#@title Rugplot(Out of scope)-> In contrast to Distributon plot you just make a dashmark for every single datapoint
sns.rugplot(tips["total_bill"])

# %%
#@title Kernel Density estimation(Out of scope)
sns.distplot(tips["total_bill"])

# %%
#@title 2.Categorical Plots
import seaborn as sns
import numpy as np
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#@title BarPlot -> It shows you the mean/average of total bill for each categorical value 
sns.barplot(x="sex",y="total_bill",data=tips)

# %%
#@title Change estimator from mean to something else for barplot
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)

# %%
#@title CountPlot -> To count number of occurences of categorical value
sns.countplot(x="sex",data=tips)

# %%
tips["sex"].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
#@title Boxplot ->  box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram.
sns.boxplot(x="day",y="total_bill",data=tips)

# %%
# Total Bill Quartile for entire dataset
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Total Bill Quartile for entire dataset based on each day
tips.groupby("day").describe()
# Out:
#      total_bill                                      ... size
#           count       mean       std   min      25%  ...  min  25%  50%  75%  max
# day                                                  ...
# Thur       62.0  17.682742  7.886170  7.51  12.4425  ...  1.0  2.0  2.0  2.0  6.0
# Fri        19.0  17.151579  8.302660  5.75  12.0950  ...  1.0  2.0  2.0  2.0  4.0
# Sat        87.0  20.441379  9.480419  3.07  13.9050  ...  1.0  2.0  2.0  3.0  5.0
# Sun        76.0  21.410000  8.832122  7.25  14.9875  ...  2.0  2.0  2.0  4.0  6.0
#
# [4 rows x 24 columns]

# %%
#@title Use hue with Boxplot to show another different boxplot for different categorical column 

sns.boxplot(x="day",y="total_bill",data=tips,hue="sex")

# %%
#@title stripplot ->  scatterplot based of the category
sns.stripplot(x="day",y="total_bill",data=tips)

# %%
#@title Split stripplot on another categorical column using hue
sns.stripplot(x="day",y="total_bill",data=tips,hue="sex",split=True,jitter=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
#Verify the above data
tips[tips["sex"]=="Male"].groupby("day").describe()
# Out:
#      total_bill                                       ... size
#           count       mean        std   min      25%  ...  min  25%  50%  75%  max
# day                                                   ...
# Thur       30.0  18.714667   8.019728  7.51  13.6975  ...  2.0  2.0  2.0  2.0  6.0
# Fri        10.0  19.857000  10.015847  8.58  12.2350  ...  1.0  2.0  2.0  2.0  4.0
# Sat        59.0  20.802542   9.836306  7.74  13.9050  ...  2.0  2.0  2.0  3.0  5.0
# Sun        58.0  21.887241   9.129142  7.25  15.1350  ...  2.0  2.0  2.0  4.0  6.0
#
# [4 rows x 24 columns]

# %%
tips[tips["sex"]=="Female"].groupby("day").describe()
# Out:
#      total_bill                                      ... size
#           count       mean       std   min      25%  ...  min  25%  50%   75%  max
# day                                                  ...
# Thur       32.0  16.715312  7.759764  8.35  12.1625  ...  1.0  2.0  2.0  2.00  6.0
# Fri         9.0  14.145556  4.788547  5.75  11.3500  ...  2.0  2.0  2.0  2.00  3.0
# Sat        28.0  19.680357  8.806470  3.07  14.0500  ...  1.0  2.0  2.0  2.25  4.0
# Sun        18.0  19.872222  7.837513  9.60  15.1750  ...  2.0  2.0  3.0  3.75  5.0
#
# [4 rows x 24 columns]

# %%
#@title 3.Matrix Plots

# %%
import seaborn as sns
import numpy as np
tips=sns.load_dataset("tips")
flights=sns.load_dataset("flights")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
#@title A heat map -> is a graphical representation of data where the individual values contained in a matrix are represented as colors. "Heat map" is a newer term but shading matrices have existed for

# %%
# Pivot flights table based on year
flight_pivot=flights.pivot(index="month",columns="year",values="passengers")

# %%
flight_pivot
# Out:
# year       1949  1950  1951  1952  1953  ...  1956  1957  1958  1959  1960
# month                                    ...
# January     112   115   145   171   196  ...   284   315   340   360   417
# February    118   126   150   180   196  ...   277   301   318   342   391
# March       132   141   178   193   236  ...   317   356   362   406   419
# April       129   135   163   181   235  ...   313   348   348   396   461
# May         121   125   172   183   229  ...   318   355   363   420   472
# June        135   149   178   218   243  ...   374   422   435   472   535
# July        148   170   199   230   264  ...   413   465   491   548   622
# August      148   170   199   242   272  ...   405   467   505   559   606
# September   136   158   184   209   237  ...   355   404   404   463   508
# October     119   133   162   191   211  ...   306   347   359   407   461
# November    104   114   146   172   180  ...   271   305   310   362   390
# ...

# %%
sns.heatmap(flight_pivot)

# %%
#@title Use cmap with heatmap to change color schme
sns.heatmap(flight_pivot,cmap="coolwarm")

# %%
#@title Use linecolor and linewidth to apply some separation
sns.heatmap(flight_pivot,cmap="coolwarm",linewidth=1,linecolor="black")

# %%
#@title A cluster map -> will cluster things an order such that similar groups are close to each other
sns.clustermap(flight_pivot,cmap="coolwarm",linewidth=1,linecolor="black")
